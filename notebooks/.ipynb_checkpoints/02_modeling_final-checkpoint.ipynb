# %%
#!pip install flaml
#!pip install xgboost
#!pip install lightgbm

import sys
import os
sys.path.append(os.path.abspath(".."))

from src.train import *
# Run training script
# Out:
# [flaml.automl.logger: 12-03 21:51:29] {1752} INFO - task = classification
# [flaml.automl.logger: 12-03 21:51:29] {1763} INFO - Evaluation method: holdout
# [flaml.automl.logger: 12-03 21:51:31] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 12-03 21:51:31] {1979} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'lrl1']
# [flaml.automl.logger: 12-03 21:51:31] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 12-03 21:51:32] {2417} INFO - Estimated sufficient time budget=343454s. Estimated necessary time budget=7951s.
# [flaml.automl.logger: 12-03 21:51:32] {2466} INFO -  at 2.8s,	estimator lgbm's best error=0.2526,	best estimator lgbm's best error=0.2526
# [flaml.automl.logger: 12-03 21:51:32] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 12-03 21:51:32] {2466} INFO -  at 2.8s,	estimator lgbm's best error=0.2526,	best estimator lgbm's best error=0.2526
# ...
