# %%
#!pip install flaml
#!pip install xgboost
#!pip install lightgbm

# Import code from "train_AutoML.py" & run training script to identify best algorithm & its setup
import sys
import os
sys.path.append(os.path.abspath(".."))

from src.train_AutoML import *
