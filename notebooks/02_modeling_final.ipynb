# %%
#!pip install flaml
#!pip install xgboost
#!pip install lightgbm
#!pip install mlflow

# Ignore warnings
import warnings 
warnings.filterwarnings("ignore")

# Import code from "train_final.py"
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.train_final import run_training

# Run code from "train_final.py"
run_training(
    data_path="data/fraud_transactions.csv", 
    register_name="fraud_model_final", 
    threshold_config="config/threshold.json", 
    retrain_reason="drift"
)
